# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
 
    return previous_row[-1]

with open('Ground-Truth-1.txt', 'r') as f:
    s1=f.read()
with open('Ground-Truth-2.txt', 'r') as f:
    s2=f.read()

with open('textlist_page_1.txt','r') as f:
    for t in f:
        fn = t.rstrip()
        with open(fn,'r') as ft:
            st = ft.read()
            print(fn)
            print(levenshtein(s1, st))

with open('textlist_page_2.txt','r') as f:
    for t in f:
        fn = t.rstrip()
        with open(fn,'r') as ft:
            st = ft.read()
            print(fn)
            print(levenshtein(s2, st))
# Out:
# bsb/bsb10502018_abbyy_1.txt
# 356
# bsb/bsb10502018_downloaded_1.txt
# 370
# bsb/bsb10502018_ts_1.txt
# 586
# bsb/bsb10502018_web_1.txt
# 649
# hathi_california/Hathi_California_abbyy_1.txt
# 4095
# hathi_california/Hathi_California_hathi_1.txt
# 434
# hathi_california/Hathi_California_ts_1.txt
# 453
# hathi_michigan/Hathi_Michigan_abbyy_1.txt
# 4104
# hathi_michigan/Hathi_Michigan_hathi_1.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7ae6c7680d49> in <module>()
#      30             st = ft.read()
#      31             print(fn)
# ---> 32             print(levenshtein(s1, st))
#      33
#      34 with open('textlist_page_2.txt','r') as f:
#
# <ipython-input-6-7ae6c7680d49> in levenshtein(s1, s2)
#       1 def levenshtein(s1, s2):
#       2     if len(s1) < len(s2):
# ----> 3         return levenshtein(s2, s1)
#       4
#       5     # len(s1) >= len(s2)
#
# <ipython-input-6-7ae6c7680d49> in levenshtein(s1, s2)
#      14             deletions = current_row[j] + 1       # than s2
#      15             substitutions = previous_row[j] + (c1 != c2)
# ---> 16             current_row.append(min(insertions, deletions, substitutions))
#      17         previous_row = current_row
#      18
#
# KeyboardInterrupt:

# %%
def levenshtein(s, t):
        ''' From Wikipedia article; Iterative with two matrix rows. '''
        if s == t: return 0
        elif len(s) == 0: return len(t)
        elif len(t) == 0: return len(s)
        v0 = [None] * (len(t) + 1)
        v1 = [None] * (len(t) + 1)
        for i in range(len(v0)):
            v0[i] = i
        for i in range(len(s)):
            v1[0] = i + 1
            for j in range(len(t)):
                cost = 0 if s[i] == t[j] else 1
                v1[j + 1] = min(v1[j] + 1, v0[j + 1] + 1, v0[j] + cost)
            for j in range(len(v0)):
                v0[j] = v1[j]
                
        return v1[len(t)]

with open('Ground-Truth-1.txt', 'r') as f:
    s1=f.read()
with open('Ground-Truth-2.txt', 'r') as f:
    s2=f.read()

with open('textlist_page_1.txt','r') as f:
    for t in f:
        fn = t.rstrip()
        with open(fn,'r') as ft:
            st = ft.read()
            print(fn)
            print(levenshtein(s1, st))

with open('textlist_page_2.txt','r') as f:
    for t in f:
        fn = t.rstrip()
        with open(fn,'r') as ft:
            st = ft.read()
            print(fn)
            print(levenshtein(s2, st))
# Out:
# bsb/bsb10502018_abbyy_1.txt
# 356
# bsb/bsb10502018_downloaded_1.txt
# 370
# bsb/bsb10502018_ts_1.txt
# 586
# bsb/bsb10502018_web_1.txt
# 649
# hathi_california/Hathi_California_abbyy_1.txt
# 4095
# hathi_california/Hathi_California_hathi_1.txt
# 434
# hathi_california/Hathi_California_ts_1.txt
# 453
# hathi_michigan/Hathi_Michigan_abbyy_1.txt
# 4104
# hathi_michigan/Hathi_Michigan_hathi_1.txt
# 496
# hathi_michigan/Hathi_Michigan_ts_1.txt
# 4194
# hathi_new_york_pl/Hathi_NY_abbyy_1.txt
# 485
# hathi_new_york_pl/Hathi_NY_hathi_1.txt
# 381
# hathi_new_york_pl/Hathi_NY_ts_1.txt
# 1206
# hathi_princeton/Hathi-Princeton_ts_1.txt
# 416
# hathi_princeton/Hathi_Princeton_abbyy_1.txt
# 408
# hathi_princeton/Hathi_Princeton_hathi_1.txt
# 481
# internet_archive/allgemeineliter142unkngoog_abbyy_1.txt
# 2069
# internet_archive/allgemeineliter142unkngoog_ia_1.txt
# 836
# internet_archive/allgemeineliter142unkngoog_ts_1.txt
# 469
# internet_archive/allgemeineliter189unkngoog_abbyy_1.txt
# 3639
# internet_archive/allgemeineliter189unkngoog_ia_1.txt
# 1673
# internet_archive/allgemeineliter189unkngoog_ts_1.txt
# 1172
# internet_archive/allgemeineliter76unkngoog_abbyy_1.txt
# 775
# internet_archive/allgemeineliter76unkngoog_ia_1.txt
# 1535
# internet_archive/allgemeineliter76unkngoog_ts_1.txt
# 775
# internet_archive/bub_gb_uaU9AAAAIAAJ_abbyy_1.txt
# 445
# internet_archive/bub_gb_uaU9AAAAIAAJ_ia_1.txt
# 835
# internet_archive/gb_uaU9AAAAIAAJ_ts_1.txt
# 410
# önb/öbn_abbyy_1.txt
# 407
# önb/öbn_ts_1.txt
# 1019
# önb/önb_önb_1.txt
# 345
# bsb/bsb10502018_abbyy_2.txt
# 430
# bsb/bsb10502018_downloaded_2.txt
# 441
# bsb/bsb10502018_ts_2.txt
# 613
# bsb/bsb10502018_web_2.txt
# 927
# hathi_california/Hathi_California_abbyy_2.txt
# 1411
# hathi_california/Hathi_California_hathi_2.txt
# 578
# hathi_california/Hathi_California_ts_2.txt
# 613
# hathi_michigan/Hathi_Michigan_abbyy_2.txt
# 4473
# hathi_michigan/Hathi_Michigan_hathi_2.txt
# 2927
# hathi_michigan/Hathi_Michigan_ts_2.txt
# 1953
# hathi_new_york_pl/Hathi_NY_abbyy_2.txt
# 457
# hathi_new_york_pl/Hathi_NY_hathi_2.txt
# 392
# hathi_new_york_pl/Hathi_NY_ts_2.txt
# 806
# hathi_princeton/Hathi-Princeton_ts_2.txt
# 566
# hathi_princeton/Hathi_Princeton_abbyy_2.txt
# 502
# hathi_princeton/Hathi_Princeton_hathi_2.txt
# 649
# internet_archive/allgemeineliter142unkngoog_abbyy_2.txt
# 775
# internet_archive/allgemeineliter142unkngoog_ia_2.txt
# 1387
# internet_archive/allgemeineliter142unkngoog_ts_2.txt
# 663
# internet_archive/allgemeineliter189unkngoog_abbyy_2.txt
# 5262
# internet_archive/allgemeineliter189unkngoog_ia_2.txt
# 2935
# internet_archive/allgemeineliter189unkngoog_ts_2.txt
# 1644
# internet_archive/allgemeineliter76unkngoog_abbyy_2.txt
# 692
# internet_archive/allgemeineliter76unkngoog_ia_2.txt
# 1191
# internet_archive/allgemeineliter76unkngoog_ts_2.txt
# 1007
# internet_archive/bub_gb_uaU9AAAAIAAJ_abbyy_2.txt
# 587
# internet_archive/bub_gb_uaU9AAAAIAAJ_ia_2.txt
# 802
# internet_archive/gb_uaU9AAAAIAAJ_ts_2.txt
# 541
# önb/öbn_abbyy_2.txt
# 557
# önb/öbn_ts_2.txt
# 1324
# önb/önb_önb_2.txt
# 413
